# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_parquet('ZQM_LIMITS_SMP_20240402_011834.parquet')
data["MATKL"].nunique()
# Out:
# 331

# %%
data["WERKS"].value_counts()
# Out:
# WERKS
# RM01    249743
# RM02    155514
# RM04    131804
# RM03     84970
# SM01      9570
# SM02      1188
# Name: count, dtype: int64

# %%
data = pd.read_csv("Raw_ZQM_MTC_RESULTS202403.csv")
data["WGHT"].sum()
# Out:
# /var/folders/r9/87gtbty52c79d176x87qqc1c0000gn/T/ipykernel_36156/1206475488.py:1: DtypeWarning: Columns (3,43,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Raw_ZQM_MTC_RESULTS202403.csv")
# 568562.2749999999

# %%
data['ZROW'].value_counts()
# Out:
# ZROW
# 1     223227
# 2     110425
# 3     105913
# 4      71957
# 5      69199
# 6      50023
# 7       1406
# 8        512
# 9         95
# 10        32
# Name: count, dtype: int64

# %%
zilohead = pd.read_csv('new_data/zilohead_2024.csv',skiprows=0, low_memory=False)
ziloitms = pd.read_csv('new_data/ziloitms_2024.csv', low_memory=False)

# %%
mtc_results = pd.read_csv('Raw_ZQM_MTC_RESULTS202403.csv',low_memory=False)

# %%
mtc_results["ZROW"].value_counts()
# Out:
# ZROW
# 1     223227
# 2     110425
# 3     105913
# 4      71957
# 5      69199
# 6      50023
# 7       1406
# 8        512
# 9         95
# 10        32
# Name: count, dtype: int64

# %%
mtc_results["WERKS"].value_counts()
# Out:
# WERKS
# RM01    249743
# RM02    155514
# RM04    131804
# RM03     84970
# SM01      9570
# SM02      1188
# Name: count, dtype: int64

# %%
# mtc_results = mtc_results[mtc_results["ZROW"] =="1"]
# mtc_results
# Out:
# Empty DataFrame
# Columns: [VBELN, ZCASTNO, ZROW, ERDAT, MATKL, ZCARBON, ZSILICON, ZMANG, ZPHOS, ZSULP, ZNITRO, ZCOPP, ZCHROM, ZMOLY, ZNICK, ZVAND, ZBORON, ZCEQ, WGHT]
# Index: []

# %%
mtc_results = pd.read_csv('Raw_ZQM_MTC_RESULTS202403.csv',low_memory=False)

mtc_results = mtc_results[mtc_results["ZROW"] ==1]
# mtc_results =  mtc_results[mtc_results["WERKS"] == "RM04"]
mtc_results = mtc_results[mtc_results["WGHT"] != 0.000]

mtc_results.drop(["PCM",
                  # "ERDAT",
                  'MANDT',
                  'ZACTMATNR',
                  'TRAID',
                  'ZCERTNO',
                  'ZCERTSEQ',
                  'ZISSDATE',
                  'GJAHR',
                  'NAME1',
                  'ZFLAG',
                  'STD',
                  "ZIMPACTJR",
                  "ZIMPACTJ0",
                  "ZIMPACTJ2",
                  "ZAVG",
                  "ZIMPACT_KEY",
                  "ZIMPACT_VAL",
                  "ZTEMP",
                  "ZRA",
                  'NB',
                  'SN',
                  'TI',
                  'AL',
                  'CA',
                  'CNT',
                  'DOKNR',
                  "ZKEY",
                  "WERKS",
                  "VBELV",
                  "VBELV",
                  "ZWEIGHT",
                  "ZCSAREA",
                  "ZCSAREA",
                  "ZYSTR",
                  "ZYSTR",
                  "ZTSTR",
                  "ZELOG",
                  "ZNMNL",
                  "ZGL",
                  "ZMAKTX",
                  "MATNR"
                  ], axis=1, inplace=True)

mtc_results.head(10)
mtc_results.drop_duplicates(inplace=True)
mtc_results.dropna(inplace=True)

# %%
# mtc_results["WERKS"].value_counts()

# %%
# phase 4 rm04 
mtc_results["WGHT"].sum()
# Out:
# 568555.9870000001

# %%
mtc_results.describe()
# Out:
#               VBELN     ZROW         ERDAT       ZCARBON      ZSILICON  \
# count  9.962200e+04  99622.0  9.962200e+04  99622.000000  99622.000000
# mean   7.649077e+07      1.0  2.023065e+07      0.176517      0.237872
# std    5.685844e+06      0.0  3.537437e+02      0.015091      0.043624
# min    1.052301e+07      1.0  2.023010e+07      0.054600      0.160333
# 25%    7.073735e+07      1.0  2.023032e+07      0.166000      0.204333
# 50%    8.050014e+07      1.0  2.023062e+07      0.178333      0.225667
# 75%    8.051780e+07      1.0  2.023093e+07      0.188367      0.264667
# max    8.053673e+07      1.0  2.023123e+07      0.240000      0.383133
#
#               ZMANG         ZPHOS         ZSULP        ZNITRO         ZCOPP  \
# count  99622.000000  99622.000000  99622.000000  99622.000000  99622.000000
# mean       1.258808      0.011573      0.010117      0.009928      0.007713
# std        0.109682      0.002915      0.002830      0.001022      0.007801
# ...

# %%
zqm_limuts = pd.read_csv('new_data/ZQM_LIMITS_SMP.csv')
zqm_limuts.drop('MANDT', axis=1, inplace=True)
zqm_limuts.drop(["WERKS","FT_FRM","FT_TO","AEDAT","AENAM","ERNAM","WGBEZ","ERDAT"], axis=1,errors="ignore", inplace=True)
zqm_limuts.dropna(inplace=True)
zqm_limuts.drop_duplicates(inplace=True)

# %%
# optional:
common_matkl = set(mtc_results["MATKL"]) & set(zqm_limuts["MATKL"])  # Find intersection
mtc_results = mtc_results[mtc_results["MATKL"].isin(common_matkl)]
zqm_limuts = zqm_limuts[zqm_limuts["MATKL"].isin(common_matkl)]

# %%
# Assuming we want to sort and keep the highest value rows for all columns except 'MATKL'
# Get all column names except 'MATKL'
sort_columns = [col for col in zqm_limuts.columns if col != 'MATKL']

# Sort by 'MATKL' and all other columns in descending order to make sure the highest values are considered last
zqm_limuts = zqm_limuts.sort_values(by=['MATKL'] + sort_columns, ascending=[True] + [False] * len(sort_columns))

# Drop duplicates in 'MATKL', keeping the last entry which, due to sorting, will have the highest values across all columns for each 'MATKL'
zqm_limuts = zqm_limuts.drop_duplicates(subset=['MATKL'], keep='last')

zqm_limuts
# Out:
#          MATKL  Z_C_HI  Z_C_LOW  Z_SI_HI  Z_SI_LOW  Z_MG_HI  Z_MG_LOW  \
# 95         085    0.24      0.0     0.55      0.00     1.60       0.0
# 97    085-2062    0.20      0.0     0.45      0.10     1.55       0.0
# 100  085-E350C    0.20      0.0     0.45      0.10     1.55       0.0
# 103     085-J2    0.20      0.0     0.55      0.00     1.60       0.0
# 108   085-J2-M    0.20      0.0     0.55      0.00     1.60       0.0
# 112      085-M    0.24      0.0     0.55      0.00     1.60       0.0
# 115        086    0.21      0.0     0.55      0.00     1.50       0.0
# 123      086-M    0.21      0.0     0.55      0.00     1.50       0.0
# 130        092    0.23      0.0     0.40      0.00     1.60       0.5
# 133        093    0.23      0.0     0.40      0.00     1.60       0.0
# 134    093-092    0.22      0.0     0.40      0.00     1.50       0.5
# 137  093-092-C    0.22      0.0     0.40      0.15     1.50       0.5
# ...

# %%
zqm_limuts
# Out:
#          MATKL  Z_C_HI  Z_C_LOW  Z_SI_HI  Z_SI_LOW  Z_MG_HI  Z_MG_LOW  \
# 95         085    0.24      0.0     0.55      0.00     1.60       0.0
# 97    085-2062    0.20      0.0     0.45      0.10     1.55       0.0
# 100  085-E350C    0.20      0.0     0.45      0.10     1.55       0.0
# 103     085-J2    0.20      0.0     0.55      0.00     1.60       0.0
# 108   085-J2-M    0.20      0.0     0.55      0.00     1.60       0.0
# 112      085-M    0.24      0.0     0.55      0.00     1.60       0.0
# 115        086    0.21      0.0     0.55      0.00     1.50       0.0
# 123      086-M    0.21      0.0     0.55      0.00     1.50       0.0
# 130        092    0.23      0.0     0.40      0.00     1.60       0.5
# 133        093    0.23      0.0     0.40      0.00     1.60       0.0
# 134    093-092    0.22      0.0     0.40      0.00     1.50       0.5
# 137  093-092-C    0.22      0.0     0.40      0.15     1.50       0.5
# ...

# %% [markdown]
# 1. MTC results MATKL is the material group, we can connect it to zqm_limits by MATKL :
# 2. Maps columns to be used by analysis so the chems or ferroalloys results of mtc results must fall in the range of zqm_limits.
# 3. visualize by material group and overshot or undershot of ferroalloys.

# %%
float_columns = [
                 'ZCARBON',
                 'ZSILICON',
                 'ZMANG',
                 'ZPHOS',
                 'ZSULP',
                 'ZNITRO',
                 'ZCOPP',
                 'ZCHROM',
                 'ZMOLY',
                 'ZNICK',
                 'ZVAND',
                 'ZBORON',
                 'ZCEQ']

mtc_results.loc[:, float_columns] = mtc_results.loc[:, float_columns].apply(lambda x: pd.to_numeric(x))
mtc_results.loc[:, "ZCARBON"] = mtc_results["ZCARBON"].astype(float)

# %%
df_2 = mtc_results.copy()
df_2.head(10)
# Out:
#         VBELN  ZCASTNO  ZROW     ERDAT  MATKL   ZCARBON  ZSILICON     ZMANG  \
# 110  20523615  2084378     1  20230918  098-M  0.112333  0.242433  1.423633
# 113  20523615  2093357     1  20230918  098-M  0.110200  0.209367  1.423067
# 116  20523615  2093359     1  20230918  098-M  0.104433  0.221633  1.447233
# 119  20523615  2093364     1  20230918  098-M  0.110767  0.242233  1.439700
# 122  20523615  2097143     1  20230918  098-M  0.105667  0.199667  1.428000
# 224  20524285  2101912     1  20230926  098-M  0.161667  0.272667  1.380667
# 227  20524285  2101913     1  20230926  098-M  0.156333  0.273667  1.376333
# 266  20524343  2101908     1  20230927  098-M  0.163667  0.270667  1.384333
# 281  20524347  2101888     1  20230927  098-M  0.159333  0.281333  1.352000
# 284  20524347  2101890     1  20230927  098-M  0.159667  0.290333  1.347000
#
#         ZPHOS     ZSULP    ZNITRO     ZCOPP    ZCHROM     ZMOLY     ZNICK  \
# ...

# %%
zqm_limuts.head(10)
# Out:
#          MATKL  Z_C_HI  Z_C_LOW  Z_SI_HI  Z_SI_LOW  Z_MG_HI  Z_MG_LOW  \
# 95         085    0.24      0.0     0.55       0.0     1.60       0.0
# 97    085-2062    0.20      0.0     0.45       0.1     1.55       0.0
# 100  085-E350C    0.20      0.0     0.45       0.1     1.55       0.0
# 103     085-J2    0.20      0.0     0.55       0.0     1.60       0.0
# 108   085-J2-M    0.20      0.0     0.55       0.0     1.60       0.0
# 112      085-M    0.24      0.0     0.55       0.0     1.60       0.0
# 115        086    0.21      0.0     0.55       0.0     1.50       0.0
# 123      086-M    0.21      0.0     0.55       0.0     1.50       0.0
# 130        092    0.23      0.0     0.40       0.0     1.60       0.5
# 133        093    0.23      0.0     0.40       0.0     1.60       0.0
#
#      Z_PH_HI  Z_PH_LOW  Z_S_HI  ...  Z_B_HI  Z_B_LOW  Z_CEQ_HI  Z_CEQ_LOW  \
# 95     0.035       0.0   0.035  ...  0.0010      0.0      0.45        0.0
# ...

# %% [markdown]
# # Results-1

# %%
common_matkl = set(mtc_results["MATKL"]) & set(zqm_limuts["MATKL"])  # Find intersection
mtc_results = mtc_results[mtc_results["MATKL"].isin(common_matkl)]

# %%
# 23 Material Groups
mtc_results["MATKL"].nunique()
# Out:
# 30

# %%
mtc_results.duplicated().sum()
# Out:
# 0

# %%
num_unique_rows = mtc_results.drop_duplicates().shape[0]
print("Number of unique MTC results:", num_unique_rows)
# Out:
# Number of unique MTC results: 99305

# %%
mtc_results["VBELN"].nunique()
# Out:
# 30253

# %%
# 107364 tons
mtc_results["WGHT"].sum()
# Out:
# 567337.9169999999

# %% [markdown]
# $$\[ S = \left( \frac{\sum_{i=k} (F_i \times W_i)}{100} \right) \times P \]$$

# %%
zqm_limuts
# Out:
#          MATKL  Z_C_HI  Z_C_LOW  Z_SI_HI  Z_SI_LOW  Z_MG_HI  Z_MG_LOW  \
# 95         085    0.24      0.0     0.55      0.00     1.60       0.0
# 97    085-2062    0.20      0.0     0.45      0.10     1.55       0.0
# 100  085-E350C    0.20      0.0     0.45      0.10     1.55       0.0
# 103     085-J2    0.20      0.0     0.55      0.00     1.60       0.0
# 108   085-J2-M    0.20      0.0     0.55      0.00     1.60       0.0
# 112      085-M    0.24      0.0     0.55      0.00     1.60       0.0
# 115        086    0.21      0.0     0.55      0.00     1.50       0.0
# 123      086-M    0.21      0.0     0.55      0.00     1.50       0.0
# 130        092    0.23      0.0     0.40      0.00     1.60       0.5
# 133        093    0.23      0.0     0.40      0.00     1.60       0.0
# 134    093-092    0.22      0.0     0.40      0.00     1.50       0.5
# 137  093-092-C    0.22      0.0     0.40      0.15     1.50       0.5
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Merge the dataframes on the 'MATKL' column
merged_df = pd.merge(df_2, zqm_limuts, on='MATKL', how='left')

# Define the composition mapping
composition_mapping = {
    "ZCARBON": "Carbon",
    "ZNITRO": "Nitrogen",
    "ZSILICON": "Silicon",
    "ZPHOS": "Phosphorus",
    "ZSULP": "Sulfur",
    "ZCOPP": "Copper",
    "ZCHROM": "Chromium",
    "ZMOLY": "Molybdenum",
    "ZNICK": "Nickel",
    "ZVAND": "Vanadium",
    "ZBORON": "Boron",
    "ZCEQ": "Carbon Equivalent"
}

# Function to check and plot the values for each key pair using seaborn
def check_ranges_seaborn(df, key_pairs):
    # Create a long-form DataFrame for easier plotting with seaborn
    plot_data = pd.DataFrame()
    for key, (high, low) in key_pairs.items():
        temp_df = df[['MATKL', key, high, low]].copy()
        temp_df.rename(columns={key: 'actual_value', high: 'high_value', low: 'low_value'}, inplace=True)
        temp_df['element'] = key
        plot_data = pd.concat([plot_data, temp_df])

    # Initialize a large enough figure to hold all subplots
    num_keys = len(key_pairs)
    plt.figure(figsize=(10, 5 * num_keys))

    # Customize font sizes
    tick_label_size = 12  # Adjust size for tick labels
    axis_label_size = 14  # Adjust size for axis labels
    title_size = 16       # Adjust size for titles

    # Plot each element in a separate subplot
    for i, element in enumerate(key_pairs.keys(), 1):
        plt.subplot(num_keys, 1, i)
        data_subset = plot_data[plot_data['element'] == element]
        sns.scatterplot(data=data_subset, x='MATKL', y='actual_value', label='Actual Value')
        sns.scatterplot(data=data_subset, x='MATKL', y='high_value', label='High Limit')
        sns.scatterplot(data=data_subset, x='MATKL', y='low_value', label='Low Limit')

        # Using composition mapping for title
        plt.title(f'Analysis for {composition_mapping[element]}', fontsize=title_size)
        plt.xlabel('MATKL', fontsize=axis_label_size)
        plt.ylabel('Values', fontsize=axis_label_size)

        # Set the font size for tick labels
        plt.xticks(rotation=90, fontsize=tick_label_size)
        plt.yticks(fontsize=tick_label_size)

        # Place the legend outside the plot
        plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

    plt.tight_layout()
    plt.show()


key_value_pairs = {

    "ZCARBON" :('Z_C_HI', 'Z_C_LOW'),
    "ZNITRO" :('Z_N2_HI', 'Z_N2_LOW'),
    "ZSILICON" :('Z_SI_HI', 'Z_SI_LOW'),
    "ZPHOS" :('Z_PH_HI', 'Z_PH_LOW'),
    "ZSULP" :('Z_S_HI', 'Z_S_LOW'),
    "ZCOPP" :('Z_CU_HI', 'Z_CU_LOW'),
    "ZCHROM" :('Z_CR_HI', 'Z_CR_LOW'),
    "ZMOLY" :('Z_MB_HI', 'Z_MB_LOW'),
    "ZNICK" :('Z_NI_HI', 'Z_NI_LOW'),
    "ZVAND" :('Z_VN_HI', 'Z_VN_LOW'),
    "ZBORON" :('Z_B_HI', 'Z_B_LOW'),
    "ZCEQ" :('Z_CEQ_HI', 'Z_CEQ_LOW'),
}

 
# Perform the range checking and plotting using seaborn
check_ranges_seaborn(merged_df, key_value_pairs)

# %% [markdown]
# # Results-2

# %%
df = mtc_results.copy()


# List of columns for which we want to calculate means and label above-mean values
columns_to_check = ['ZCARBON',
                    'ZSILICON',
                    'ZMANG',
                    'ZPHOS',
                    'ZSULP',
                    'ZNITRO',
                    'ZCOPP',
                    'ZCHROM',
                    'ZMOLY',
                    'ZNICK',
                    'ZVAND',
                    'ZBORON',
                    'ZCEQ']


group_means = df.groupby('MATKL')[columns_to_check].mean().reset_index()

group_means = group_means.rename(columns={col: f'mean_{col}' for col in columns_to_check})

df = df.merge(group_means, on='MATKL', how='left')

# For each column, create a new column that indicates if the value is above the group mean
for col in columns_to_check:
    df[f'is_above_mean_{col}'] = df[col] > 1.2 * df[f'mean_{col}']
    df[f'points_above_mean_{col}'] = df[col] - df[f'mean_{col}']
    df[f'weighted_tons_{col}'] = df['WGHT'] * df[f'points_above_mean_{col}'] /100


# weighted_tons_col=(WGHT×points_above_mean_col)/100

# %%
df_silicon =df[df["is_above_mean_ZSILICON"] == True]
df_silicon[['MATKL','mean_ZSILICON','points_above_mean_ZSILICON','weighted_tons_ZSILICON','WGHT']]
df_silicon = df_silicon[df_silicon["MATKL"] == "085-M"]
df_silicon = df_silicon[['MATKL','mean_ZSILICON','points_above_mean_ZSILICON','weighted_tons_ZSILICON','WGHT']]
# df_silicon

# %% [markdown]
# The total cost of excess ferroalloy consumption for a specific type \( f \) across all batches is calculated with the following formula:
#
# $$
# \[
# \text{Total Cost} = \sum_{i=1}^{n} \max\left(C_{i,f} - \frac{\sum_{j=1}^{n} C_{j,f}}{n}, 0\right) \times p_f
# \]
# $$
#
#
#
# - $$\( C_{i,f} \)$$ represents the consumption of ferroalloy type \( f \) for the batch \( i \).
# - \( n \) is the total number of batches for the steel grade being analyzed.
# - \( p_f \) is the price per unit of the ferroalloy type \( f \).
#
# ### Explanation:
# - **Mean Consumption Calculation**: $$\( \frac{\sum_{j=1}^{n} C_{j,f}}{n} \)$$ computes the average consumption of ferroalloy type \( f \) across all batches, providing a baseline for comparison.
# - **Excess Calculation**: For each batch, $$\( \max\left(C_{i,f} - \text{mean}, 0\right) \)$$ determines the excess consumption by comparing each batch's consumption to the average. If a batch's consumption is less than or equal to the average, the excess is considered zero.
# - **Cost Calculation**: The excess (if any) is then multiplied by the price $$\( p_f \)$$, resulting in the cost for that batch. The total cost is the sum of these individual costs across all batches.

# %%
df
# Out:
#           VBELN  ZCASTNO  ZROW     ERDAT  MATKL   ZCARBON  ZSILICON     ZMANG  \
# 0      20523615  2084378     1  20230918  098-M  0.112333  0.242433  1.423633
# 1      20523615  2093357     1  20230918  098-M  0.110200  0.209367  1.423067
# 2      20523615  2093359     1  20230918  098-M  0.104433  0.221633  1.447233
# 3      20523615  2093364     1  20230918  098-M  0.110767  0.242233  1.439700
# 4      20523615  2097143     1  20230918  098-M  0.105667  0.199667  1.428000
# ...         ...      ...   ...       ...    ...       ...       ...       ...
# 99300  80536729  2100588     1  20231231    086  0.175000  0.241333  1.212667
# 99301  80536729  2100629     1  20231231    086  0.167333  0.297000  1.171000
# 99302  80536730  2100584     1  20231231    086  0.159333  0.268667  1.172000
# 99303  80536730  2100588     1  20231231    086  0.175000  0.241333  1.212667
# 99304  80536731  2103558     1  20231231  086-M  0.170000  0.329667  1.162000
#
# ...

# %%
df.to_csv("final_results_2024.csv")

# %%
ZNITRO_towards_high = df[df["is_above_mean_ZNITRO"] == True]
ZSILICON_towards_high = df[df["is_above_mean_ZSILICON"] == True]
ZPHOS_towards_high = df[df["is_above_mean_ZPHOS"] == True]
ZSULP_towards_high = df[df["is_above_mean_ZSULP"] == True]
ZCOPP_towards_high = df[df["is_above_mean_ZCOPP"] == True]
ZCHROM_towards_high = df[df["is_above_mean_ZCHROM"] == True]
ZMOLY_towards_high = df[df["is_above_mean_ZMOLY"] == True]
ZNICK_towards_high = df[df["is_above_mean_ZNICK"] == True]
ZVAND_towards_high = df[df["is_above_mean_ZVAND"] == True]
ZBORON_towards_high = df[df["is_above_mean_ZBORON"] == True]
ZCEQ_towards_high = df[df["is_above_mean_ZCEQ"] == True]
ZMANG_towards_high = df[df["is_above_mean_ZMANG"] == True]
ZCARBON_towards_high = df[df["is_above_mean_ZCARBON"] == True]

# %%
results = {
    "Silicon":ZSILICON_towards_high["weighted_tons_ZSILICON"].sum(),
    "Chromium": ZCHROM_towards_high["weighted_tons_ZCHROM"].sum(),
    "Molybdenum": ZMOLY_towards_high["weighted_tons_ZMOLY"].sum(),
    "Nickel": ZNICK_towards_high["weighted_tons_ZNICK"].sum() ,
    "Vanadium": ZVAND_towards_high["weighted_tons_ZVAND"].sum(),
    "Manganese": ZMANG_towards_high["weighted_tons_ZMANG"].sum(),
}


results
# Out:
# {'Silicon': 79.13906333303913,
#  'Chromium': 7.156238727566412,
#  'Molybdenum': 2.5049207286595054,
#  'Nickel': 9.298588973552611,
#  'Vanadium': 20.223833626184362,
#  'Manganese': 1.5604468038707417}

# %%
# Prices per ton for each material
prices_per_ton = {
    "Silicon": 6247,
    "Chromium": 6143,
    "Molybdenum": 45537,
    "Nickel": 53802,
    "Vanadium": 100700,
    "Manganese": 5418,
}

prices_per_ton
# Out:
# {'Silicon': 6247,
#  'Chromium': 6143,
#  'Molybdenum': 45537,
#  'Nickel': 53802,
#  'Vanadium': 100700,
#  'Manganese': 5418}

# %%
total_costs = {material: results[material] * prices_per_ton[material] for material in results}
total_costs
# Out:
# {'Silicon': 494381.72864149546,
#  'Chromium': 43960.774503440465,
#  'Molybdenum': 114066.5752209679,
#  'Nickel': 500282.6839550776,
#  'Vanadium': 2036540.0461567652,
#  'Manganese': 8454.500783371679}

# %%
overall_total_cost = sum(total_costs.values())
overall_total_cost
# Out:
# 3197686.309261118

# %%
results
# Out:
# {'Silicon': 79.13906333303913,
#  'Chromium': 7.156238727566412,
#  'Molybdenum': 2.5049207286595054,
#  'Nickel': 9.298588973552611,
#  'Vanadium': 20.223833626184362,
#  'Manganese': 1.5604468038707417}

# %%
# tons overshot:
sum(list(results.values()))
# Out:
# 119.88309219287277

# %%
# overall tons produced
df["WGHT"].sum()
# Out:
# 567337.9169999999

# %%
costs = {key: results[key] * prices_per_ton[key] for key in results}

# Convert the costs dictionary to a DataFrame for easier plotting
costs_df = pd.DataFrame(list(costs.items()), columns=['Ferroalloy', 'Cost'])

# Creating the bar plot
plt.figure(figsize=(12, 8))  # Increased figure size for better display
bar_plot = sns.barplot(x='Ferroalloy', y='Cost', data=costs_df)
plt.title('Cost of Overshooting Ferroalloys from Mean Material Group', fontsize=20)  # Increase font size for the title
plt.xlabel('Ferroalloy', fontsize=16)  # Increase font size for x-axis label
plt.ylabel('Total Cost (AED)', fontsize=16)  # Increase font size for y-axis label
plt.xticks(rotation=45, fontsize=14)  # Rotate and increase font size of x-axis ticks
plt.yticks(fontsize=14)  # Increase font size of y-axis ticks

# Annotating the bars with the exact cost values
for p in bar_plot.patches:
    bar_plot.annotate(format(p.get_height(), ',.2f'),
                      (p.get_x() + p.get_width() / 2., p.get_height()),
                      ha='center', va='center',
                      xytext=(0, 9),
                      textcoords='offset points',
                      fontsize=12)  # Optional: adjust annotation font size if needed

plt.show()

# %% [markdown]
# $$
# C = (F_i - \overline{F}) * P
# $$
# *   <span class="math-inline">C</span> represents the overshot cost
# *   <span class="math-inline">F\_i</span> represents individual ferroalloys consumption
# *   <span class="math-inline">\\overline\{F\}</span> is the mean ferroalloys consumption
# *   <span class="math-inline">P</span> is the ferroalloys price

# %%
key_value_pairs = {

    "ZCARBON" :('Z_C_HI', 'Z_C_LOW'),
    "ZNITRO" :('Z_N2_HI', 'Z_N2_LOW'),
    "ZSILICON" :('Z_SI_HI', 'Z_SI_LOW'),
    "ZPHOS" :('Z_PH_HI', 'Z_PH_LOW'),
    "ZSULP" :('Z_S_HI', 'Z_S_LOW'),
    "ZCOPP" :('Z_CU_HI', 'Z_CU_LOW'),
    "ZCHROM" :('Z_CR_HI', 'Z_CR_LOW'),
    "ZMOLY" :('Z_MB_HI', 'Z_MB_LOW'),
    "ZNICK" :('Z_NI_HI', 'Z_NI_LOW'),
    "ZVAND" :('Z_VN_HI', 'Z_VN_LOW'),

    "ZBORON" :('Z_B_HI', 'Z_B_LOW'),
    "ZCEQ" :('Z_CEQ_HI', 'Z_CEQ_LOW'),
}

def within_range(value, high, low):
    return low <= value <= high

for index, row in mtc_results.iterrows():
    matkl = row["MATKL"]  # Get the MATKL for this row

    for key, (high_col, low_col) in key_value_pairs.items():


        high_limit = zqm_limuts.loc[zqm_limuts["MATKL"] == matkl, high_col].iloc[0]
        low_limit = zqm_limuts.loc[zqm_limuts["MATKL"] == matkl, low_col].iloc[0]

        value = row[key]
        in_range = within_range(value, high_limit, low_limit)

        results_df.loc[index, key + "_within_range"] = in_range  # Store True/False based on check


# 
# def closer_to(value, high, low):
# 
#     # Calculate the difference between the value and each limit
#     high_diff = abs(value - high)
#     low_diff = abs(value - low)
# 
#     # Return 'high' or 'low' based on which difference is smaller
#     if high_diff < low_diff:
#         return "closer to high"
#     elif low_diff < high_diff:
#         return "closer to low"
#     else:
#         return "equally close to both"
# 
# for index, row in mtc_results.iterrows():
#     matkl = row["MATKL"]  # Get the MATKL for this row
# 
#     for key, (high_col, low_col) in key_value_pairs.items():
# 
#         # Get high and low limits for the MATKL
#         high_limit = zqm_limuts.loc[zqm_limuts["MATKL"] == matkl, high_col].iloc[0]
#         low_limit = zqm_limuts.loc[zqm_limuts["MATKL"] == matkl, low_col].iloc[0]
# 
#         # Get the value from the current row
#         value = row[key]
# 
#         # Determine if the value is closer to high or low
#         closeness = closer_to(value, high_limit, low_limit)
# 
#         # Store the result in results_df
#         results_df.loc[index, key + "_closeness"] = closeness





# closeness_columns = [col for col in results_df.columns if 'closeness' in col]
# closeness_columns.append("MATKL")
# # closeness_columns
# 
# 
# da =results_df[closeness_columns]
# da[closeness_columns] = da[closeness_columns].replace('closer to high', 'high')
# da[closeness_columns] = da[closeness_columns].replace('closer to low', 'low')
# # da.columns.tolist()
# # closeness_columns.remove("MATKL")
# 
# 
# 
# # Count the occurrences of 'high' and 'low' in each column
# high_low_counts = {}
# 
# for column in closeness_columns:
#     high_count = da[column].apply(lambda x: 1 if str(x).lower() == 'high' else 0).sum()
#     low_count = da[column].apply(lambda x: 1 if str(x).lower() == 'low' else 0).sum()
#     high_low_counts[column] = {'high': high_count, 'low': low_count}
# 
# # Convert to a DataFrame for easier plotting
# counts_df = pd.DataFrame(high_low_counts).T
# 
# # Reset index and rename columns for better readability in plots
# counts_df = counts_df.reset_index().rename(columns={'index': 'Element'})
# 
# # Use Seaborn to create a bar plot with multiple bars for "high" and "low"
# plt.figure(figsize=(18, 6))
# sns.barplot(x='Element', y='value', hue='variable', data=counts_df.melt(id_vars='Element'))
# plt.title('Count of High and Low in Each Closeness Column')
# plt.ylabel('Count')
# plt.xlabel('Closeness Column')
# plt.xticks(rotation=45, ha='right')  # rotate by 45 degrees and align to the right
# plt.show()


# composition_mapping = {
#     "ZCARBON": "Carbon",
#     "ZNITRO": "Nitrogen",
#     "ZSILICON": "Silicon",
#     "ZPHOS": "Phosphorus",
#     "ZSULP": "Sulfur",
#     "ZCOPP": "Copper",
#     "ZCHROM": "Chromium",
#     "ZMOLY": "Molybdenum",
#     "ZNICK": "Nickel",
#     "ZVAND": "Vanadium",
#     "ZBORON": "Boron",
#     "ZCEQ": "Carbon Equivalent"
# }
# 
# high_low_counts = pd.DataFrame({
#     "Composition": [col.split("_")[0] for col in results_df.columns if "_closer_to_high" in col],
#     "Closer to High": [results_df[col].sum() for col in results_df.columns if "_closer_to_high" in col],
#     "Closer to Low": [results_df[col.replace("_closer_to_high", "_closer_to_low")].sum() for col in results_df.columns if "_closer_to_high" in col],
# })
# 
# plt.figure(figsize=(14, 6))
# sns.barplot(data=high_low_counts.melt(id_vars=["Composition"], var_name="Closer To", value_name="Count"),
#             x="Composition", y="Count", hue="Closer To", palette="coolwarm")
# 
# plt.title("Count of Values Closer to High and Closer to Low for Each Composition")
# plt.xlabel("Composition")
# plt.ylabel("Count")
# plt.xticks(rotation=45)
# plt.show()
# 
# mtc_results.columns.tolist()
# 
# 
# for col in columns_to_check:
#     plt.figure(figsize=(18, 6))
#     sns.barplot(x='MATKL', y=f'weighted_tons_{col}', data=df, ci=None)
#     plt.title(f"Weighted Tons for Points Above the Mean ({col})")
#     plt.xlabel("Group (MATKL)")
#     plt.ylabel("Weighted Tons")
#     plt.xticks(rotation=45)  # Rotate labels by 45 degrees
#     plt.show()


# 
# columns_ = df.columns.tolist()
# filtered_strings = [s for s in columns_ if 'is_above_mean_' in s]
# # filtered_strings
# # df_filtered = df[df[[f'is_above_mean_{col}' for col in columns_to_check]].any(axis=1)]
# # df_filtered 
# # df[df[filtered_strings] == True]
# # df_filtered
# filtered_strings
# 
# 
# 
# resul_ZCARBON = df[df["is_above_mean_ZCARBON"] == True]
# resul_ZSILICON = df[df["is_above_mean_ZSILICON"] == True]
# resul_ZMANG = df[df["is_above_mean_ZMANG"] == True]
# result_ZPHOS = df[df["is_above_mean_ZPHOS"] == True]
# 
# 
# result_ZSULP = df[df["is_above_mean_ZSULP"] == True]
# result_ZNITRO = df[df["is_above_mean_ZNITRO"] == True]
# result_ZCOPP = df[df["is_above_mean_ZCOPP"] == True]
# result_ZCHROM = df[df["is_above_mean_ZCHROM"] == True]
# 
# 
# result_ZMOLY = df[df["is_above_mean_ZMOLY"] == True]
# result_ZNICK = df[df["is_above_mean_ZNICK"] == True]
# result_ZVAND = df[df["is_above_mean_ZVAND"] == True]
# result_ZBORON = df[df["is_above_mean_ZBORON"] == True]
# result_ZCEQ = df[df["is_above_mean_ZCEQ"] == True]
# 
# resul_ZCARBON["weighted_tons_ZCARBON"].sum()
# resul_ZSILICON["weighted_tons_ZSILICON"].sum()
# resul_ZMANG["weighted_tons_ZMANG"].sum()
# result_ZPHOS["weighted_tons_ZPHOS"].sum()
# result_ZSULP["weighted_tons_ZSULP"].sum()
# result_ZNITRO["weighted_tons_ZNITRO"].sum()
# result_ZCOPP["weighted_tons_ZCOPP"].sum()
# result_ZCHROM["weighted_tons_ZCHROM"].sum()
# result_ZMOLY["weighted_tons_ZMOLY"].sum()
# result_ZNICK["weighted_tons_ZNICK"].sum()
# result_ZVAND["weighted_tons_ZVAND"].sum()
# result_ZVAND["weighted_tons_ZVAND"].sum()
# result_ZBORON["weighted_tons_ZBORON"].sum()
# result_ZCEQ["weighted_tons_ZCEQ"].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 33
#      30 value = row[key]
#      31 in_range = within_range(value, high_limit, low_limit)
# ---> 33 results_df.loc[index, key + "_within_range"] = in_range
#
# NameError: name 'results_df' is not defined

# %%
# composition_names = {
#     "ZCARBON": "Carbon",
#     "ZSILICON": "Silicon",
#     "ZMANG": "Manganese",
#     "ZPHOS": "Phosphorus",
#     "ZSULP": "Sulfur",
#     "ZNITRO": "Nitrogen",
#     "ZCOPP": "Copper",
#     "ZCHROM": "Chromium",
#     "ZMOLY": "Molybdenum",
#     "ZNICK": "Nickel",
#     "ZVAND": "Vanadium",
#     "ZBORON": "Boron",
#     "ZCEQ": "Carbon Equivalent",
# }

# results = {
#     "Carbon": resul_ZCARBON["weighted_tons_ZCARBON"].sum(),
#     "Silicon": resul_ZSILICON["weighted_tons_ZSILICON"].sum(),
#     "Manganese": resul_ZMANG["weighted_tons_ZMANG"].sum(),
#     "Phosphorus": result_ZPHOS["weighted_tons_ZPHOS"].sum(),
#     "Sulfur": result_ZSULP["weighted_tons_ZSULP"].sum(),
#     "Nitrogen": result_ZNITRO["weighted_tons_ZNITRO"].sum(),
#     "Copper": result_ZCOPP["weighted_tons_ZCOPP"].sum(),
#     "Chromium": result_ZCHROM["weighted_tons_ZCHROM"].sum(),
#     "Molybdenum": result_ZMOLY["weighted_tons_ZMOLY"].sum(),
#     "Nickel": result_ZNICK["weighted_tons_ZNICK"].sum(),
#     "Vanadium": result_ZVAND["weighted_tons_ZVAND"].sum(),
#     "Boron": result_ZBORON["weighted_tons_ZBORON"].sum(),
#     "Carbon Equivalent": result_ZCEQ["weighted_tons_ZCEQ"].sum(),
# }

# Prices per ton for each material
# prices_per_ton = {
#     "Carbon": 0,
#     "Silicon": 0,
#     "Manganese": 0,
#     "Phosphorus": 0,
#     "Sulfur": 0,
#     "Nitrogen": 0,
#     "Copper": 0,
#     "Chromium": 0,
#     "Molybdenum": 0,
#     "Nickel": 53802.13,
#     "Vanadium": 100700.0,
#     "Boron": 0,
#     "Carbon Equivalent": 0,
# }
# 
# # Calculate total cost for each material
# total_costs = {material: results[material] * prices_per_ton[material] for material in results}
# 
# # Calculate the overall total cost
# overall_total_cost = sum(total_costs.values())
# 
# # print("Total costs for each material:", total_costs)
# # print("Overall total cost:", overall_total_cost)
# 
# total_costs
# result_ZVAND["weighted_tons_ZVAND"].sum()
# result_ZVAND["weighted_tons_ZVAND"].sum() * 100700.0
# result_ZNICK["weighted_tons_ZNICK"].sum() *


# 
result_ZMOLY["weighted_tons_ZMOLY"].sum()

results = {
    "ZCARBON": 100,
    "ZSILICON": 200,
    "ZMANG": 150,
    "ZPHOS": 50,
    "ZSULP": 75,
    "ZNITRO": 120,
    "ZCOPP": 180,
    "ZCHROM": 220,
    "ZMOLY": 130,
    "ZNICK": 90,
    "ZVAND": 170,
    "ZBORON": 65,
    "ZCEQ": 140,
}

# # Mapping of abbreviation to actual composition names
composition_names = {
    "ZCARBON": "Carbon",
    "ZSILICON": "Silicon",
    "ZMANG": "Manganese",
    "ZPHOS": "Phosphorus",
    "ZSULP": "Sulfur",
    "ZNITRO": "Nitrogen",
    "ZCOPP": "Copper",
    "ZCHROM": "Chromium",
    "ZMOLY": "Molybdenum",
    "ZNICK": "Nickel",
    "ZVAND": "Vanadium",
    "ZBORON": "Boron",
    "ZCEQ": "Carbon Equivalent",
}
# 
# # Update results with the actual composition names
# results_with_real_names = {composition_names[key]: value for key, value in results.items()}
# 
# results_with_real_names


# Create a dataframe to count the rows that are above the mean for each column
# above_mean_count = pd.DataFrame(
#     {
#         'Column': columns_to_check,
#         'Above Mean Count': [df[f'is_above_mean_{col}'].sum() for col in columns_to_check]
#     }
# )
# 
# # Plot the count of rows that are above the mean for each column
# plt.figure(figsize=(12, 6))
# sns.barplot(x='Column', y='Above Mean Count', data=above_mean_count)
# plt.title("Count of Rows Above the Mean for Each Column")
# plt.xlabel("Column")
# plt.ylabel("Count of Rows Above the Mean")
# plt.show()

# %%
# keys = [
    # 'ZELOG', # Likely represents the concept of "Elog," which could be related to electronic logging or a similar process in the steelmaking industry.
    # 'ZCARBON',
    # Represents the carbon (C) content in steel.
    # Z_C_HI / Z_C_LOW: Carbon (C) high and low limits.
    # 'ZNITRO', # Represents nitrogen (N), which can affect steel's mechanical properties.
    # Z_N2_HI / Z_N2_LOW: Nitrogen (N) high and low limits.
    # 'ZSILICON', #  Refers to silicon (Si), commonly used to deoxidize steel.
    # Z_SI_HI / Z_SI_LOW: Silicon (Si) high and low limits.
    # 'ZPHOS', # Represents phosphorus (P), an impurity that can affect steel quality.
    # Z_PH_HI / Z_PH_LOW: Phosphorus (P) high and low limits.
    # 'ZSULP', # Refers to sulfur (S), another impurity.
    # Z_S_HI / Z_S_LOW: Sulfur (S) high and low limits.
    'ZCOPP', # Indicates copper (Cu), used to improve corrosion resistance.
    # Z_CU_HI / Z_CU_LOW: Copper (Cu) high and low limits.
    'ZCHROM', # Refers to chromium (Cr), key in stainless steel production. 
    # Z_CR_HI / Z_CR_LOW: Chromium (Cr) high and low limits.
    'ZMOLY', # Represents molybdenum (Mo), used for high-strength steel. 
    # Z_MB_HI / Z_MB_LOW: Molybdenum (Mo) high and low limits.
    'ZNICK', # Refers to nickel (Ni), essential in stainless steel. 
    # Z_NI_HI / Z_NI_LOW: Nickel (Ni) high and low limits.
    'ZVAND', # Represents vanadium (V), used for high-strength steel.
    # Z_VN_HI / Z_VN_LOW: Vanadium (V) high and low limits.
    'ZBORON', # Refers to boron (B), used to increase hardness and strength.
    # Z_B_HI / Z_B_LOW: Boron (B) high and low limits.
    'ZCEQ' # Represents the carbon equivalent, a measure of carbon content and alloying elements used to predict steel's weldability and hardness.
    # Z_CEQ_HI / Z_CEQ_LOW: Carbon Equivalent high and low limits, indicating weldability.
    # incomplete mapping:
    'ZNMNL', # Refers to the manganese (Mn) content in steel.
    'ZMANG', # Another reference to manganese (Mn).
    'ZGL', #Typically stands for galvanized steel, indicating zinc (Zn) coating.
    # Z_TI_HI / Z_TI_LOW: Titanium (Ti) high and low limits.
    # Z_NB_HI / Z_NB_LOW: Niobium (Nb) high and low limits.
    # Z_SN_HI / Z_SN_LOW: Tin (Sn) high and low limits.
]


# values = {
#     'ZNMNL': ('Z_SI_HI', 'Z_SI_LOW'),
#     'ZELOG': ('Z_C_HI', 'Z_C_LOW'),
#     'ZGL': ('Z_MG_HI', 'Z_MG_LOW'),
#     'ZCARBON': ('Z_PH_HI', 'Z_PH_LOW'),
#     'ZSILICON': ('Z_S_HI', 'Z_S_LOW'),
#     'ZMANG': ('Z_N2_HI', 'Z_N2_LOW'),
#     'ZPHOS': ('Z_CU_HI', 'Z_CU_LOW'),
#     'ZSULP': ('Z_CR_HI', 'Z_CR_LOW'),
#     'ZNITRO': ('Z_MB_HI', 'Z_MB_LOW'),
#     'ZCOPP': ('Z_NI_HI', 'Z_NI_LOW'),
#     'ZCHROM': ('Z_VN_HI', 'Z_VN_LOW'),
#     'ZMOLY': ('Z_B_HI', 'Z_B_LOW'),
#     'ZNICK': ('Z_CEQ_HI', 'Z_CEQ_LOW'),
#     'ZVAND': ('Z_TI_HI', 'Z_TI_LOW'),
#     'ZBORON': ('Z_NB_HI', 'Z_NB_LOW'),
#     'ZCEQ': ('Z_SN_HI', 'Z_SN_LOW')
# }
# Z_MG_HI / Z_MG_LOW: Magnesium (Mg) high and low limits.

# Defining the values for each key from the second list in pairs of high and low
# Create a dictionary with the keys and corresponding high/low value pairs
# key_value_pairs = {key: values[key] for key in keys}
# key_value_pairs

# %%
# {'VBELN':"delivery number",
#  'ZCASTNO':"cast number",
#  'ZROW':"one cast can have multiple results",
#  'MATNR':"any number start with 4 is rm-4",
#  'ERDAT':"date of the mtc creation. 99% same as dispatch",
#  'MATKL':"matrail group",
#  'ZMAKTX':"matrial description",
#  'WERKS':"plant",
#  'VBELV':"sales order",
#  'ZKEY':"form number or name,",
#  'ZWEIGHT':"nominal weight",
#  'ZCSAREA':"cross section area",
#  'ZYSTR':"yeild strength",
#  'ZTSTR':"strentgh",
#  'ZELOG',
#  'ZNMNL',
#  'ZCARBON':"carbon",
#  'PCM': might need formula for carbon calculations"}



# mtc_results_for_analysis = mtc_results[mtc_results["MATKL"].isin(zqm_limuts["MATKL"])]
# mtc_results_for_analysis.columns.tolist()
# 
# 
# 
# 
# # load number to connec to ziloitms,ZLONO
# # sales order number,ZSALENO
# # delivery number,ZDELYNO
# 
# zilohead = zilohead[['ZLONO',"ZSALENO","ZDELYNO"]]
# zilohead = zilohead.iloc[1:]
# zilohead["ZSALENO"]  = zilohead["ZSALENO"].astype(int)
# zilohead.head(10)
# zilohead[zilohead["ZSALENO"].isin(ziloitms["ZSALENO"])].head(10)


### for cost calculation we need to connect ziloitms with mtc_results how many ordereds are dispatched with what quantity:



# 'ZLONO',: ILO number create delivery based on this one,
# 'ZSALENO',sales order number 
# 'ZPOSNR', sales order items sales order might multiple items item ID, 
# 'ZMATNR',product code,
# 'ZARKTX',product description,
# 'ZDLYQTY'dispatched quantity
# ziloitms["ZSALENO"] = ziloitms["ZSALENO"].astype(int)
# ziloitms = ziloitms.iloc[1:]
# ziloitms.head(10)


# mtc_results[mtc_results["VBELV"].isin(ziloitms["ZSALENO"])]

### connect MTC results to ziloitms by sales order:


# {'VBELN':"delivery number",
#  'ZCASTNO':"cast number",
#  'ZROW':"one cast can have multiple results",
#  'MATNR':"any number start with 4 is rm-4",
#  'ERDAT':"date of the mtc creation. 99% same as dispatch",
#  'MATKL':"matrail group",
#  'ZMAKTX':"matrial description",
#  'WERKS':"plant",
#  'VBELV':"sales order",
#  'ZKEY':"form number or name,",
#  'ZWEIGHT':"nominal weight",
#  'ZCSAREA':"cross section area",
#  'ZYSTR':"yeild strength",
#  'ZTSTR':"strentgh",
#  'ZELOG',
#  'ZNMNL',
#  'ZCARBON':"carbon",
#  'PCM': might need formula for carbon calculations"}

# mtc_results = mtc_results.iloc[1:]
# mtc_results.head(10)


# sales order connect:
