# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Composition Consumption and Cost Calculation
#
# To accurately calculate the composition consumption and its corresponding cost for a given grade of steel, we follow a two-step process. This approach first determines the actual amount of composition used in kilograms (kg) and then calculates the cost based on the price per ton.
#
# ### Step 1: Calculate Composition Consumption in Kilograms (kg)
#
# Given variables:
# - `C` = Composition consumption rate in kg of composition per ton of billets
# - `T` = Tons of billets produced
#
# The formula to calculate the actual consumption of the composition (`A`) in kilograms (kg) for that grade of steel is:
#
# $$\[A = C \times T\]$$
#
# ### Step 2: Convert Consumption into Cost
#
# Given additional variable:
# $$ `P` = Price of the sheet (or composition) per ton$$
#
# Since the price `P` is provided per ton, and there are 1000 kg in a ton, we first convert the actual consumption from kilograms to tons (`A_tons`):
#
# $$\[A_{\text{tons}} = \frac{A}{1000}\]$$
#
# To calculate the total cost (`Cost`) of the composition based on its consumption and the sheet price per ton, we use the formula:
#
# $$\[Cost = A_{\text{tons}} \times P\]$$
#
# Combining the steps, we get the comprehensive formula for calculating cost:
#
# $$\[Cost = \left( \frac{C \times T}{1000} \right) \times P\]$$
#
# This formula allows us to calculate the total cost of the composition used based on its consumption rate per ton of billets produced, the total tons of billets produced, and the price per ton of the composition.
#
# composition consumption in kg/ton * tons of billets produced = composition consumption in KG
#  1.   kg/ton * ton = kg you get the actual consumption of composition for that grade steel
#  2.   from 1, divide by 1000 to get ton, multiply the result by tth sheet price ton * (sheet price since its per ton) per composition.

# %% [markdown]
# ## Prices for SMP2 Chemicals:

# %%
# Given dictionaries
list_names_prices_smp2_december_2023 = {
    "FeSi - Ferro-Silicon": 1784.26869542229,
    "FeSiMn - Silicon-maganese": 982.491100414191,
    "FeMnHC - Ferro-Manganese (High Carbon)": 1072.38667899182,
    "Recarburizer - Recarburizer": 459.168109303317,
    'FeCr - Ferrochrome': 0.0
}

list_names_prices_smp2_februrary_2024 = {
    "FeSi - Ferro-Silicon": 1513.14266939651,
    "FeSiMn - Silicon-maganese": 981.166637222105,
    "FeMnHC - Ferro-Manganese (High Carbon)": 987.371168766638,
    "Recarburizer - Recarburizer": 396.65551241767,
    'FeCr - Ferrochrome': 0.0
}

list_names_prices_smp2_january_2024 = {
    "FeSi - Ferro-Silicon": 1761.04858264133,
    "FeSiMn - Silicon-maganese": 1761.04858264133,
    "FeMnHC - Ferro-Manganese (High Carbon)": 1013.54162166185,
    "Recarburizer - Recarburizer": 485.931625802038,
    'FeCr - Ferrochrome': 0.0
}

list_names_prices_smp2_november_2023 = {
    "FeSi - Ferro-Silicon": 1813.81793731061,
    "FeSiMn - Silicon-maganese": 1068.45538821339,
    "FeMnHC - Ferro-Manganese (High Carbon)": 1072.38820871572,
    "Recarburizer - Recarburizer": 541.481184711259,
    'FeCr - Ferrochrome': 0.0
}

df = pd.DataFrame([
    list_names_prices_smp2_december_2023,
    list_names_prices_smp2_februrary_2024,
    list_names_prices_smp2_january_2024,
    list_names_prices_smp2_november_2023
])

mean_prices = df.mean()
list_names_prices_smp2_mean = mean_prices.to_dict()
list_names_prices_smp2_mean
# Out:
# {'FeSi - Ferro-Silicon': 1718.069471192685,
#  'FeSiMn - Silicon-maganese': 1198.290427122754,
#  'FeMnHC - Ferro-Manganese (High Carbon)': 1036.421919534007,
#  'Recarburizer - Recarburizer': 470.809108058571,
#  'FeCr - Ferrochrome': 0.0}

# %%
def plot_ferroalloys_comparison_modified(dataframe):

    long_df = dataframe.melt(id_vars="SteelGrade", var_name="Type", value_name="KG/Ton")

    plt.figure(figsize=(18, 10))
    sns.barplot(data=long_df, x="SteelGrade", y="KG/Ton", hue="Type")
    plt.title("Ferroalloys Target vs Actual vs OverShot (KG/Ton) by Steel Grade", fontsize=22)
    plt.xticks(rotation=90, fontsize=14)
    plt.ylabel("KG/Ton", fontsize=24)
    plt.xlabel("Steel Grade", fontsize=24)
    plt.legend(title='', title_fontsize='18', labelspacing=0.95)
    plt.tight_layout()
    plt.show()


def add_suffix_to_duplicates(dataframe, column_name):

    df = dataframe.copy()
    df['counter'] = df.groupby(column_name).cumcount() + 1
    df[column_name] = df.apply(lambda row: f"{row[column_name]}_{row['counter']}", axis=1)
    df.drop('counter', axis=1, inplace=True)

    return df


def calculate_overshot_cost(dataframe, overshot_column_name, cost_per_ton):

    df = dataframe.copy()
    df["KG used " + overshot_column_name] = df[overshot_column_name] * df["Billet"]
    df["Tons used " + overshot_column_name] = df["KG used " + overshot_column_name] / 1000
    df[overshot_column_name + "  Cost"] = df["Tons used " + overshot_column_name ] * cost_per_ton
    return df

# %%
data = pd.read_csv("Ferroalloys Consumption SMP #2.csv")

# add filter here:
# target_columns = [col for col in data.columns if 'target' in col.lower()]
# data[target_columns] = data[target_columns] * 1.025

# %%
data['Ferroalloys Overshot (KG/Ton)'] = data['Ferroalloys Actual (KG/Ton)'] - data['Ferroalloys Target (KG/Ton)']
data['FeSiMn Overshot (KG/Ton)'] = data['FeSiMn Actual (KG/Ton)'] - data['FeSiMn Target (KG/Ton)']
data['FeSi Overshot (KG/Ton)'] = data['FeSi Actual (KG/Ton)'] - data['FeSi Target (KG/Ton)']

# %%
# filtered:
filtered_by_overshot = data[(data["Ferroalloys Overshot (KG/Ton)"] > 0.0) & (data["Ferroalloys Target (KG/Ton)"] != 0)].copy()
overall_ferroalloys =  filtered_by_overshot[["SteelGrade","Ferroalloys Target (KG/Ton)","Ferroalloys Actual (KG/Ton)","Ferroalloys Overshot (KG/Ton)"]]
overall_FeSiMn = filtered_by_overshot[["SteelGrade","FeSiMn Overshot (KG/Ton)", "FeSiMn Target (KG/Ton)","FeSiMn Actual (KG/Ton)","Billet"]]
overall_FeSi = filtered_by_overshot[["SteelGrade","FeSi Overshot (KG/Ton)","FeSi Target (KG/Ton)","FeSi Actual (KG/Ton)","Billet"]]

# %%
overall_ferroalloys_ = overall_ferroalloys.copy()
target_columns = [col for col in overall_ferroalloys_.columns if 'Target (KG/Ton)' in col]
mask = (overall_ferroalloys_[target_columns] != 0.0).any(axis=1)
overall_ferroalloys_ = overall_ferroalloys_.loc[mask]
overall_ferroalloys_ = add_suffix_to_duplicates(overall_ferroalloys_, 'SteelGrade')
plot_ferroalloys_comparison_modified(overall_ferroalloys_)

# %%
mean_cost_per_ton_FeSiMn = 1198.290427122754
overall_FeSiMn_ = overall_FeSiMn.copy()
target_columns = [col for col in overall_FeSiMn_.columns if 'Target (KG/Ton)' in col]
mask = (overall_FeSiMn_[target_columns] != 0.0).any(axis=1)
overall_FeSiMn_ = overall_FeSiMn_.loc[mask]
overall_FeSiMn_ = add_suffix_to_duplicates(overall_FeSiMn_, 'SteelGrade')
overall_FeSiMn_["KG Used FeSiMn - Overshot"] = overall_FeSiMn_["FeSiMn Overshot (KG/Ton)"]  * overall_FeSiMn_["Billet"]
overall_FeSiMn_["Tons used FeSiMn - Overshot"] = overall_FeSiMn_["KG Used FeSiMn - Overshot"]/1000
overall_FeSiMn_["Overshot FeSiMn Cost"] = overall_FeSiMn_["Tons used FeSiMn - Overshot"] * mean_cost_per_ton_FeSiMn
# overall_FeSiMn_.drop(columns=['Billet','KG Used FeSiMn - Overshot','Tons used FeSiMn - Overshot'],axis=1,inplace=True)
overall_FeSiMn_
# Out:
#           SteelGrade  FeSiMn Overshot (KG/Ton)  FeSiMn Target (KG/Ton)  \
# 8    AISI 1006 CAQ_1                      1.64                     1.5
# 10       AISI 1012_1                      1.39                     6.5
# 11       AISI 1012_2                      1.23                     6.5
# 22    BS-G500B R51_1                      2.97                     7.4
# 30           EM12K_1                     -0.14                    12.1
# 31         ER70S-6_1                     -1.41                     9.0
# 33  KWSB500BWR R12_1                      0.84                     9.0
# 37       S275 JR-A_1                      1.04                    13.6
# 41      S355 G11-A_1                      2.12                    16.4
# 42      S355 G11-A_2                      0.70                    16.4
# 57        SAE 1012_1                      2.16                     6.5
# 64        SWRH 47A_1                     -2.43                     8.5
# 68        SWRH 62A_1                     -2.37                     8.5
# 74         SWRY 11_1                      0.95                     1.5
#
#     FeSiMn Actual (KG/Ton)     Billet  KG Used FeSiMn - Overshot  \
# 8                     3.14  14217.135                23316.10140
# 10                    7.89    127.478                  177.19442
# 11                    7.73   2847.713                 3502.68699
# 22                   10.37   1242.724                 3690.89028
# 30                   11.96    125.307                  -17.54298
# 31                    7.59  18400.142               -25944.20022
# 33                    9.84   1364.831                 1146.45804
# 37                   14.64  23003.444                23923.58176
# 41                   18.52   1886.049                 3998.42388
# 42                   17.10   5001.665                 3501.16550
# 57                    8.66    129.499                  279.71784
# 64                    6.07    262.802                 -638.60886
# 68                    6.13    261.369                 -619.44453
# 74                    2.45  14536.372                13809.55340
#
#     Tons used FeSiMn - Overshot  Overshot FeSiMn Cost
# 8                     23.316101          27939.461105
# 10                     0.177194            212.330377
# 11                     3.502687           4197.236289
# 22                     3.690890           4422.758490
# 30                    -0.017543            -21.021585
# 31                   -25.944200         -31088.686763
# 33                     1.146458           1373.789694
# 37                    23.923582          28667.399005
# 41                     3.998424           4791.273059
# 42                     3.501166           4195.413102
# 57                     0.279718            335.183210
# 64                    -0.638609           -765.238884
# 68                    -0.619445           -742.274450
# 74                    13.809553          16547.855642

# %%
Chem ="FeSi"
mean_cost_per_ton_FeSi = 1718.069471192685
overall_FeSi_ = overall_FeSi.copy()
target_columns = [col for col in overall_FeSi_.columns if 'Target (KG/Ton)' in col]
mask = (overall_FeSi_[target_columns] != 0.0).any(axis=1)
overall_FeSi_ = overall_FeSi_.loc[mask]
overall_FeSi_ = add_suffix_to_duplicates(overall_FeSi_, 'SteelGrade')
overall_FeSi_["KG Used FeSi - Overshot"] = overall_FeSi_["FeSi Overshot (KG/Ton)"]  * overall_FeSi_["Billet"]
overall_FeSi_["Tons used FeSi - Overshot"] = overall_FeSi_["KG Used FeSi - Overshot"]/1000
overall_FeSi_["Overshot FeSi Cost"] = overall_FeSi_["Tons used FeSi - Overshot"] * mean_cost_per_ton_FeSi
# overall_FeSi_.drop(columns=['Billet','KG Used FeSi - Overshot','Tons used FeSi - Overshot'],axis=1,inplace=True)
overall_FeSi_
# Out:
#           SteelGrade  FeSi Overshot (KG/Ton)  FeSi Target (KG/Ton)  \
# 10       AISI 1012_1                    0.76                   2.0
# 11       AISI 1012_2                    0.27                   2.0
# 22    BS-G500B R51_1                   -0.95                   2.0
# 30           EM12K_1                    0.22                   2.0
# 33  KWSB500BWR R12_1                   -0.09                   2.0
# 37       S275 JR-A_1                    0.14                   2.1
# 41      S355 G11-A_1                    0.47                   1.6
# 42      S355 G11-A_2                   -1.23                   1.6
# 57        SAE 1012_1                    0.19                   2.0
#
#     FeSi Actual (KG/Ton)     Billet  KG Used FeSi - Overshot  \
# 10                  2.76    127.478                 96.88328
# 11                  2.27   2847.713                768.88251
# 22                  1.05   1242.724              -1180.58780
# 30                  2.22    125.307                 27.56754
# 33                  1.91   1364.831               -122.83479
# 37                  2.24  23003.444               3220.48216
# 41                  2.07   1886.049                886.44303
# 42                  0.37   5001.665              -6152.04795
# 57                  2.19    129.499                 24.60481
#
#     Tons used FeSi - Overshot  Overshot FeSi Cost
# 10                   0.096883          166.452206
# 11                   0.768883         1320.993567
# 22                  -1.180588        -2028.331857
# 30                   0.027568           47.362949
# 33                  -0.122835         -211.038703
# 37                   3.220482         5533.012082
# 41                   0.886443         1522.970708
# 42                  -6.152048       -10569.645768
# 57                   0.024605           42.272773

# %%
overall_FeSiMn_["Overshot FeSiMn Cost"].sum()
# Out:
# 60065.47829341215

# %%
overall_FeSi_["Overshot FeSi Cost"].sum()
# Out:
# -4175.9520439618245

# %%
overall_FeSiMn_["Overshot FeSiMn Cost"].sum() + overall_FeSi_["Overshot FeSi Cost"].sum()
# Out:
# 55889.526249450326

# %%
# arrange the tables here and do manual calculation to get the right results:
overall_FeSiMn_ = overall_FeSiMn_.rename(columns={'Billet': 'Billet Mass (Tons)'})
overall_FeSiMn_ = overall_FeSiMn_.rename(columns={'Tons used FeSiMn - Overshot': 'FeSiMn - Overshot (Tons)'})
overall_FeSiMn_ = overall_FeSiMn_.rename(columns={'Overshot FeSiMn Cost': 'Overshot FeSiMn Cost ($USD)'})
overall_FeSiMn_ = overall_FeSiMn_.drop(columns=['KG Used FeSiMn - Overshot','FeSiMn Actual (KG/Ton)',"FeSiMn Target (KG/Ton)"],axis=1,errors="ignore")
overall_FeSiMn_ = overall_FeSiMn_[overall_FeSiMn_['Overshot FeSiMn Cost ($USD)'] >= 0]
overall_FeSiMn_
# Out:
#           SteelGrade  FeSiMn Overshot (KG/Ton)  Billet Mass (Tons)  \
# 8    AISI 1006 CAQ_1                      1.64           14217.135
# 10       AISI 1012_1                      1.39             127.478
# 11       AISI 1012_2                      1.23            2847.713
# 22    BS-G500B R51_1                      2.97            1242.724
# 33  KWSB500BWR R12_1                      0.84            1364.831
# 37       S275 JR-A_1                      1.04           23003.444
# 41      S355 G11-A_1                      2.12            1886.049
# 42      S355 G11-A_2                      0.70            5001.665
# 57        SAE 1012_1                      2.16             129.499
# 74         SWRY 11_1                      0.95           14536.372
#
#     FeSiMn - Overshot (Tons)  Overshot FeSiMn Cost ($USD)
# 8                  23.316101                 27939.461105
# 10                  0.177194                   212.330377
# 11                  3.502687                  4197.236289
# 22                  3.690890                  4422.758490
# 33                  1.146458                  1373.789694
# 37                 23.923582                 28667.399005
# 41                  3.998424                  4791.273059
# 42                  3.501166                  4195.413102
# 57                  0.279718                   335.183210
# 74                 13.809553                 16547.855642

# %%
overall_FeSiMn_["Overshot FeSiMn Cost ($USD)"].sum()
# Out:
# 92682.69997543772

# %%
# arrange the tables here and do manual calculation to get the right results:
overall_FeSi_ = overall_FeSi_.rename(columns={'Billet': 'Billet Mass (Tons)'})
overall_FeSi_ = overall_FeSi_.rename(columns={'Tons used FeSi - Overshot': 'FeSi - Overshot (Tons)'})
overall_FeSi_ = overall_FeSi_.rename(columns={'Overshot FeSi Cost': 'Overshot FeSi Cost ($USD)'})
overall_FeSi_ = overall_FeSi_.drop(columns=['KG Used FeSi - Overshot','FeSi Actual (KG/Ton)',"FeSi Target (KG/Ton)"],axis=1,errors="ignore")
overall_FeSi_ = overall_FeSi_[overall_FeSi_['Overshot FeSi Cost ($USD)'] >= 0]
overall_FeSi_
# Out:
#       SteelGrade  FeSi Overshot (KG/Ton)  Billet Mass (Tons)  \
# 10   AISI 1012_1                    0.76             127.478
# 11   AISI 1012_2                    0.27            2847.713
# 30       EM12K_1                    0.22             125.307
# 37   S275 JR-A_1                    0.14           23003.444
# 41  S355 G11-A_1                    0.47            1886.049
# 57    SAE 1012_1                    0.19             129.499
#
#     FeSi - Overshot (Tons)  Overshot FeSi Cost ($USD)
# 10                0.096883                 166.452206
# 11                0.768883                1320.993567
# 30                0.027568                  47.362949
# 37                3.220482                5533.012082
# 41                0.886443                1522.970708
# 57                0.024605                  42.272773

# %%
final_results = pd.merge(overall_FeSiMn_, overall_FeSi_, on=['SteelGrade', 'Billet Mass (Tons)'],how="outer")
final_results["Ferroalloys Overshot (KG/Ton)"] = final_results["FeSiMn Overshot (KG/Ton)"] + final_results["FeSi Overshot (KG/Ton)"]
final_results["Ferroalloys Overshot (Tons)"] =  final_results["FeSiMn - Overshot (Tons)"] + final_results["FeSi - Overshot (Tons)"]
final_results["Ferroalloys Overshot Cost ($USD)"] = final_results["Overshot FeSiMn Cost ($USD)"] + final_results["Overshot FeSi Cost ($USD)"]
final_results
# Out:
#           SteelGrade  FeSiMn Overshot (KG/Ton)  Billet Mass (Tons)  \
# 0    AISI 1006 CAQ_1                      1.64           14217.135
# 1        AISI 1012_1                      1.39             127.478
# 2        AISI 1012_2                      1.23            2847.713
# 3     BS-G500B R51_1                      2.97            1242.724
# 4            EM12K_1                       NaN             125.307
# 5   KWSB500BWR R12_1                      0.84            1364.831
# 6        S275 JR-A_1                      1.04           23003.444
# 7       S355 G11-A_1                      2.12            1886.049
# 8       S355 G11-A_2                      0.70            5001.665
# 9         SAE 1012_1                      2.16             129.499
# 10         SWRY 11_1                      0.95           14536.372
#
#     FeSiMn - Overshot (Tons)  Overshot FeSiMn Cost ($USD)  \
# 0                  23.316101                 27939.461105
# 1                   0.177194                   212.330377
# 2                   3.502687                  4197.236289
# 3                   3.690890                  4422.758490
# 4                        NaN                          NaN
# 5                   1.146458                  1373.789694
# 6                  23.923582                 28667.399005
# 7                   3.998424                  4791.273059
# 8                   3.501166                  4195.413102
# 9                   0.279718                   335.183210
# 10                 13.809553                 16547.855642
#
#     FeSi Overshot (KG/Ton)  FeSi - Overshot (Tons)  Overshot FeSi Cost ($USD)  \
# 0                      NaN                     NaN                        NaN
# 1                     0.76                0.096883                 166.452206
# 2                     0.27                0.768883                1320.993567
# 3                      NaN                     NaN                        NaN
# 4                     0.22                0.027568                  47.362949
# 5                      NaN                     NaN                        NaN
# 6                     0.14                3.220482                5533.012082
# 7                     0.47                0.886443                1522.970708
# 8                      NaN                     NaN                        NaN
# 9                     0.19                0.024605                  42.272773
# 10                     NaN                     NaN                        NaN
#
#     Ferroalloys Overshot (KG/Ton)  Ferroalloys Overshot (Tons)  \
# 0                             NaN                          NaN
# 1                            2.15                     0.274078
# 2                            1.50                     4.271570
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# 5                             NaN                          NaN
# 6                            1.18                    27.144064
# 7                            2.59                     4.884867
# 8                             NaN                          NaN
# 9                            2.35                     0.304323
# 10                            NaN                          NaN
#
#     Ferroalloys Overshot Cost ($USD)
# 0                                NaN
# 1                         378.782583
# 2                        5518.229857
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                       34200.411087
# 7                        6314.243767
# 8                                NaN
# 9                         377.455983
# 10                               NaN

# %%
final_results["Overshot FeSiMn Cost ($USD)"].sum()
# Out:
# 92682.69997543772

# %%
final_results["Overshot FeSi Cost ($USD)"].sum()
# Out:
# 8633.064284188618

# %%
final_results["Overshot FeSi Cost ($USD)"].sum() + final_results["Overshot FeSiMn Cost ($USD)"].sum()
# Out:
# 101315.76425962633

# %%
final_results["Ferroalloys Overshot (Tons)"].sum()
# Out:
# 36.87890068000003

# %%
final_results.style.background_gradient()
# Out:
# <style type="text/css">
# #T_21677_row0_col1 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_21677_row0_col2 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_21677_row0_col3, #T_21677_row0_col4 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_21677_row0_col5, #T_21677_row0_col6, #T_21677_row0_col7, #T_21677_row0_col8, #T_21677_row0_col9, #T_21677_row0_col10, #T_21677_row3_col5, #T_21677_row3_col6, #T_21677_row3_col7, #T_21677_row3_col8, #T_21677_row3_col9, #T_21677_row3_col10, #T_21677_row4_col1, #T_21677_row4_col3, #T_21677_row4_col4, #T_21677_row4_col8, #T_21677_row4_col9, #T_21677_row4_col10, #T_21677_row5_col5, #T_21677_row5_col6, #T_21677_row5_col7, #T_21677_row5_col8, #T_21677_row5_col9, #T_21677_row5_col10, #T_21677_row8_col5, #T_21677_row8_col6, #T_21677_row8_col7, #T_21677_row8_col8, #T_21677_row8_col9, #T_21677_row8_col10, #T_21677_row10_col5, #T_21677_row10_col6, #T_21677_row10_col7, #T_21677_row10_col8, #T_21677_row10_col9, #T_21677_row10_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_21677_row1_col1 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_21677_row1_col2, #T_21677_row1_col3, #T_21677_row1_col4, #T_21677_row1_col9, #T_21677_row1_col10, #T_21677_row4_col2, #T_21677_row4_col6, #T_21677_row4_col7, #T_21677_row6_col5, #T_21677_row6_col8, #T_21677_row8_col1, #T_21677_row9_col2, #T_21677_row9_col6, #T_21677_row9_col7, #T_21677_row9_col9, #T_21677_row9_col10 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_21677_row1_col5, #T_21677_row3_col1, #T_21677_row6_col2, #T_21677_row6_col3, #T_21677_row6_col4, #T_21677_row6_col6, #T_21677_row6_col7, #T_21677_row6_col9, #T_21677_row6_col10, #T_21677_row7_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_21677_row1_col6, #T_21677_row1_col7 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_21677_row1_col8 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_21677_row2_col1, #T_21677_row2_col6, #T_21677_row2_col7 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_21677_row2_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_21677_row2_col3, #T_21677_row2_col4, #T_21677_row8_col3, #T_21677_row8_col4 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_21677_row2_col5, #T_21677_row8_col2 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_21677_row2_col8 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_21677_row2_col9, #T_21677_row2_col10, #T_21677_row3_col3, #T_21677_row3_col4, #T_21677_row6_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_21677_row3_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_21677_row4_col5 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_21677_row5_col1 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_21677_row5_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_21677_row5_col3, #T_21677_row5_col4 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_21677_row7_col1 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_21677_row7_col2 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_21677_row7_col3, #T_21677_row7_col4 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_21677_row7_col5 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_21677_row7_col6, #T_21677_row7_col7 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_21677_row7_col9 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_21677_row7_col10 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_21677_row9_col1 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_21677_row9_col3, #T_21677_row9_col4 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_21677_row9_col5 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_21677_row9_col8 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_21677_row10_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_21677_row10_col2 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_21677_row10_col3, #T_21677_row10_col4 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_21677">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21677_level0_col0" class="col_heading level0 col0" >SteelGrade</th>
#       <th id="T_21677_level0_col1" class="col_heading level0 col1" >FeSiMn Overshot (KG/Ton)</th>
#       <th id="T_21677_level0_col2" class="col_heading level0 col2" >Billet Mass (Tons)</th>
#       <th id="T_21677_level0_col3" class="col_heading level0 col3" >FeSiMn - Overshot (Tons)</th>
#       <th id="T_21677_level0_col4" class="col_heading level0 col4" >Overshot FeSiMn Cost ($USD)</th>
#       <th id="T_21677_level0_col5" class="col_heading level0 col5" >FeSi Overshot (KG/Ton)</th>
#       <th id="T_21677_level0_col6" class="col_heading level0 col6" >FeSi - Overshot (Tons)</th>
#       <th id="T_21677_level0_col7" class="col_heading level0 col7" >Overshot FeSi Cost ($USD)</th>
#       <th id="T_21677_level0_col8" class="col_heading level0 col8" >Ferroalloys Overshot (KG/Ton)</th>
#       <th id="T_21677_level0_col9" class="col_heading level0 col9" >Ferroalloys Overshot (Tons)</th>
#       <th id="T_21677_level0_col10" class="col_heading level0 col10" >Ferroalloys Overshot Cost ($USD)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21677_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21677_row0_col0" class="data row0 col0" >AISI 1006 CAQ_1</td>
#       <td id="T_21677_row0_col1" class="data row0 col1" >1.640000</td>
#       <td id="T_21677_row0_col2" class="data row0 col2" >14217.135000</td>
#       <td id="T_21677_row0_col3" class="data row0 col3" >23.316101</td>
#       <td id="T_21677_row0_col4" class="data row0 col4" >27939.461105</td>
#       <td id="T_21677_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_21677_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_21677_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_21677_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_21677_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_21677_row0_col10" class="data row0 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_21677_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_21677_row1_col0" class="data row1 col0" >AISI 1012_1</td>
#       <td id="T_21677_row1_col1" class="data row1 col1" >1.390000</td>
#       <td id="T_21677_row1_col2" class="data row1 col2" >127.478000</td>
#       <td id="T_21677_row1_col3" class="data row1 col3" >0.177194</td>
#       <td id="T_21677_row1_col4" class="data row1 col4" >212.330377</td>
#       <td id="T_21677_row1_col5" class="data row1 col5" >0.760000</td>
#       <td id="T_21677_row1_col6" class="data row1 col6" >0.096883</td>
#       <td id="T_21677_row1_col7" class="data row1 col7" >166.452206</td>
#       <td id="T_21677_row1_col8" class="data row1 col8" >2.150000</td>
#       <td id="T_21677_row1_col9" class="data row1 col9" >0.274078</td>
#       <td id="T_21677_row1_col10" class="data row1 col10" >378.782583</td>
#     </tr>
#     <tr>
#       <th id="T_21677_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_21677_row2_col0" class="data row2 col0" >AISI 1012_2</td>
#       <td id="T_21677_row2_col1" class="data row2 col1" >1.230000</td>
#       <td id="T_21677_row2_col2" class="data row2 col2" >2847.713000</td>
#       <td id="T_21677_row2_col3" class="data row2 col3" >3.502687</td>
#       <td id="T_21677_row2_col4" class="data row2 col4" >4197.236289</td>
#       <td id="T_21677_row2_col5" class="data row2 col5" >0.270000</td>
#       <td id="T_21677_row2_col6" class="data row2 col6" >0.768883</td>
#       <td id="T_21677_row2_col7" class="data row2 col7" >1320.993567</td>
#       <td id="T_21677_row2_col8" class="data row2 col8" >1.500000</td>
#       <td id="T_21677_row2_col9" class="data row2 col9" >4.271570</td>
#       <td id="T_21677_row2_col10" class="data row2 col10" >5518.229857</td>
#     </tr>
#     <tr>
#       <th id="T_21677_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_21677_row3_col0" class="data row3 col0" >BS-G500B R51_1</td>
#       <td id="T_21677_row3_col1" class="data row3 c

# %%
# example calculation 1.64 /1000 * (14217) = overshot tons 
# overshot tons  * mean cost of 4 months of that chemicals:  1198.290427122754
# 23.31588 * 1198.290427122754

# %% [markdown]
# SMP2 2023 Base estimates:
# FeSiMn overshot Cost: 92682 USD
# FeSi Overshot Cost: 8633 USD
# Overall Cost: 101315 USD
# Ferroalloys Overshot (Tons): 36
#
# SMP2 2023 Conservative estimates:
# FeSiMn overshot Cost: 57085 USD
# FeSi Overshot Cost: 2656 USD
# Overall Cost: 59741 USD
# Ferroalloys Overshot (Tons): 8
